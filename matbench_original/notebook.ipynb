# %%
# import necessary packages including matbench
import os
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error
from matplotlib import pyplot as plt
from matbench.bench import MatbenchBenchmark

# %%
# import the crabnet algorthim and its functions
from crabnet.train_crabnet import get_model, load_model, get_results

# %%
# Defining a number of helper function to prepare the data for the CrabNet algorthim

# condesne_formula takes a material and returns the chemical formula in the correct format for CrabNet
def condense_formula(mat):
    if isinstance(mat, str):
        return mat
    else:
        return mat.formula.replace(" ", "")


# change_input runs condesne_formula on all the input data used for training
def change_input(train_inputs):
    inputs = []
    for input in train_inputs:
        inputs.append(condense_formula(input))
    return inputs


# make_df creates a data frame containing the train inputs and outputs for CrabNet
def make_df(train_inputs, train_outputs):
    input_df = pd.DataFrame({"formula": train_inputs, "target": train_outputs})
    return input_df


# make_df_test creates a data frame containing the test inputs for CrabNet
def make_df_test(test_inputs):
    test_df = pd.DataFrame({"formula": test_inputs})
    test_df["target"] = np.nan
    return test_df


# split_train_val splits the training data into two sets: training and validation
def split_train_val(df):
    df = df.sample(frac=1.0, random_state=7)
    val_df = df.sample(frac=0.25, random_state=7)
    train_df = df.drop(val_df.index)

    return train_df, val_df

# %%
# Defining a subset containing all of the regression tasks from the matbench tasks
subset = ["matbench_expt_gap"]

mb = MatbenchBenchmark(autoload=False, subset=subset)
data_dir = "data/matbench_temp"
os.makedirs(data_dir, exist_ok=True)

results_dict = {}

maes = []
for task in mb.tasks:
    task.load()
    mat_prop = task.dataset_name
    os.makedirs(f"{data_dir}/{mat_prop}", exist_ok=True)
    for fold in task.folds:
        train_inputs, train_outputs = task.get_train_and_val_data(fold)
        test_inputs, test_outputs = task.get_test_data(fold, include_target=True)

        # Preparing the inputs data for CrabNet
        inputs = change_input(train_inputs)
        df = make_df(inputs, train_outputs)
        test_df = make_df(test_inputs, test_outputs)

        # Creating the training and validation sets
        train_df, val_df = split_train_val(df)
        # train_df.to_csv(f"{data_dir}/{mat_prop}/train.csv")
        # val_df.to_csv(f"{data_dir}/{mat_prop}/val.csv")

        # Getting and preparing the testing data
        test_inputs = change_input(test_inputs)
        output_df = make_df_test(test_inputs)
        output_df.to_csv(f"{data_dir}/{mat_prop}/test.csv")

        # Training CrabNet
        model = get_model(
            train_df, val_df, mat_prop, classification=False, verbose=True
        )

        # Predicting on the testing data
        model = load_model(model, mat_prop, False, test_df, verbose=True)
        model, output = get_results(model)

        # Recording our data!
        predictions = output[1]
        task.record(fold, predictions)
        
        mae = mean_absolute_error(predictions, test_outputs)
        maes.append(mae)


# Saving our results
mb.to_file("my_models_benchmark.json")
print(np.mean(maes))
# Out:
# 2022-02-05 09:03:58 INFO     Initialized benchmark 'matbench_v0.1' with 1 tasks:
# ['matbench_expt_gap']
# 2022-02-05 09:03:58 INFO     Loading dataset 'matbench_expt_gap'...
# 2022-02-05 09:03:58 INFO     Dataset 'matbench_expt_gap loaded.
#
# Model architecture: out_dims, d_model, N, heads
# 3, 512, 3, 4
# Running on compute device: cuda:0
# Model size: 11987206 parameters
# Generating EDM: 100%|██████████| 2762/2762 [00:00<00:00, 125884.72formulae/s]
# loading data with up to 4 elements in the formula
# training with batchsize 128 (2**7.000)
# Generating EDM: 100%|██████████| 921/921 [00:00<00:00, 115418.86formulae/s]
# loading data with up to 4 elements in the formula
# stepping every 220 training passes, cycling lr every 10 epochs
# checkin at 20 epochs to match lr scheduler
# Epoch: 0/40 --- train mae: 1.03 val mae: 0.954
# Epoch: 19/40 --- train mae: 0.309 val mae: 0.405
# Epoch: 39/40 --- train mae: 0.188 val mae: 0.363
# Saving network (DataFrame_property) to models/trained_models/DataFrame_property.pth
# Generating EDM: 100%|██████████| 921/921 [00:00<00:00, 131913.47formulae/s]
# loading data with up to 4 elements in the formula
# 2022-02-05 09:04:44 INFO     Recorded fold matbench_expt_gap-0 successfully.
# Model architecture: out_dims, d_model, N, heads
# 3, 512, 3, 4
# Running on compute device: cuda:0
# Model size: 11987206 parameters
# Generating EDM: 100%|██████████| 2762/2762 [00:00<00:00, 98908.58formulae/s]
# loading data with up to 4 elements in the formula
# training with batchsize 128 (2**7.000)
# Generating EDM: 100%|██████████| 921/921 [00:00<00:00, 102604.42formulae/s]
# loading data with up to 4 elements in the formula
# stepping every 220 training passes, cycling lr every 10 epochs
# checkin at 20 epochs to match lr scheduler
# Epoch: 0/40 --- train mae: 0.998 val mae: 1.02
# Epoch: 19/40 --- train mae: 0.304 val mae: 0.458
# Epoch: 39/40 --- train mae: 0.185 val mae: 0.407
# Saving network (DataFrame_property) to models/trained_models/DataFrame_property.pth
# Generating EDM: 100%|██████████| 921/921 [00:00<00:00, 184697.78formulae/s]
# loading data with up to 4 elements in the formula
# 2022-02-05 09:05:28 INFO     Recorded fold matbench_expt_gap-1 successfully.
# Model architecture: out_dims, d_model, N, heads
# 3, 512, 3, 4
# Running on compute device: cuda:0
# Model size: 11987206 parameters
# Generating EDM: 100%|██████████| 2762/2762 [00:00<00:00, 125891.56formulae/s]
# loading data with up to 4 elements in the formula
# training with batchsize 128 (2**7.000)
# Generating EDM: 100%|██████████| 921/921 [00:00<00:00, 153927.08formulae/s]
# loading data with up to 4 elements in the formula
# stepping every 220 training passes, cycling lr every 10 epochs
# checkin at 20 epochs to match lr scheduler
# Epoch: 0/40 --- train mae: 0.947 val mae: 1.04
# Epoch: 19/40 --- train mae: 0.258 val mae: 0.48
# Epoch: 39/40 --- train mae: 0.152 val mae: 0.442
# Saving network (DataFrame_property) to models/trained_models/DataFrame_property.pth
# Generating EDM: 100%|██████████| 921/921 [00:00<00:00, 153945.48formulae/s]
# loading data with up to 4 elements in the formula
# 2022-02-05 09:06:12 INFO     Recorded fold matbench_expt_gap-2 successfully.
# Model architecture: out_dims, d_model, N, heads
# 3, 512, 3, 4
# Running on compute device: cuda:0
# Model size: 11987206 parameters
# Generating EDM: 100%|██████████| 2762/2762 [00:00<00:00, 74846.99formulae/s]
# loading data with up to 4 elements in the formula
# training with batchsize 128 (2**7.000)
# Generating EDM: 100%|██████████| 921/921 [00:00<00:00, 153927.08formulae/s]
# loading data with up to 4 elements in the formula
# stepping every 220 training passes, cycling lr every 10 epochs
# checkin at 20 epochs to match lr scheduler
# Epoch: 0/40 --- train mae: 0.96 val mae: 0.956
# Epoch: 19/40 --- train mae: 0.282 val mae: 0.434
# Epoch: 39/40 --- train mae: 0.164 val mae: 0.398
# Saving network (DataFrame_property) to models/trained_models/DataFrame_property.pth
# Generating EDM: 100%|██████████| 921/921 [00:00<00:00, 184697.78formulae/s]
# loading data with up to 4 elements in the formula
# 2022-02-05 09:06:57 INFO     Recorded fold matbench_expt_gap-3 successfully.
# Model architecture: out_dims, d_model, N, heads
# 3, 512, 3, 4
# Running on compute device: cuda:0
# Model size: 11987206 parameters
# Generating EDM: 100%|██████████| 2763/2763 [00:00<00:00, 95528.61formulae/s]
# loading data with up to 4 elements in the formula
# training with batchsize 128 (2**7.000)
# Generating EDM: 100%|██████████| 921/921 [00:00<00:00, 115436.11formulae/s]
# loading data with up to 4 elements in the formula
# stepping every 220 training passes, cycling lr every 10 epochs
# checkin at 20 epochs to match lr scheduler
# Epoch: 0/40 --- train mae: 0.991 val mae: 0.976
# Epoch: 19/40 --- train mae: 0.276 val mae: 0.346
# Epoch: 39/40 --- train mae: 0.158 val mae: 0.314
# Saving network (DataFrame_property) to models/trained_models/DataFrame_property.pth
# Generating EDM: 100%|██████████| 920/920 [00:00<00:00, 153759.95formulae/s]
# loading data with up to 4 elements in the formula
# 2022-02-05 09:07:42 INFO     Recorded fold matbench_expt_gap-4 successfully.
# 2022-02-05 09:07:42 INFO     Successfully wrote MatbenchBenchmark to file 'my_models_benchmark.json'.
# 0.37030038453237096
